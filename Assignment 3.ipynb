# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("netflix_data.csv")
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %% [markdown]
# # LOC

# %%
# data.loc[<row labels>, <column labels>]
data.loc[:,["type"]].value_counts()
# Out:
# type
# Movie      5377
# TV Show    2410
# dtype: int64

# %%
arr = data.loc[1,"cast"].split(", ")
print(arr)
# Out:
# ['Demián Bichir', 'Héctor Bonilla', 'Oscar Serrano', 'Azalia Ortiz', 'Octavio Michel', 'Carmen Beato']

# %%
data.loc[1,"cast"]
# Out:
# 'Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato'

# %%
len(arr)
# Out:
# 6

# %% [markdown]
# # add a col in this existing dataset
# # col of cast num_of_cast
# # ILOC

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
# One Hot Encoding
# data["cast"] = data['cast'].replace(np.nan, "None")
data["director"] = data['director'].replace(np.nan, "None")
data
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                  None  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.loc[data.release_year >= 2020].count()
# Out:
# show_id         899
# type            899
# title           899
# director        899
# cast            777
# country         827
# date_added      899
# release_year    899
# duration        899
# description     899
# genre           899
# dtype: int64

# %% [markdown]
# # Assignment Questions:

# %% [markdown]
# # Add New Column of num_of_cast

# %%
# data["num_of_cast"] = data['cast'].replace(np.nan, "None")

# %%
data = data.assign(num_of_cast = data.type)

# %%
data['num_of_cast'].replace(['TV Show', 'Movie'],[0, 1], inplace=True)

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%               None
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
print("The total number of cast in that particular movie or Tv-Show:")
print(data['num_of_cast'].value_counts())
# Out:
# The total number of cast in that particular movie or Tv-Show:
# 1    5377
# 0    2410
# Name: num_of_cast, dtype: int64

# %% [markdown]
# # GroupBy

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%               None
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
data.groupby("type").groups
# Out:
# {'Movie': [1, 2, 3, 4, 6, 7, 8, 9, 10, 13, 14, 15, 17, 18, 19, 20, 21, 22, 23, 25, 27, 28, 30, 31, 32, 33, 34, 35, 36, 37, 39, 40, 41, 42, 43, 44, 46, 47, 48, 49, 50, 52, 54, 55, 56, 57, 59, 60, 62, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 81, 82, 83, 84, 88, 89, 90, 91, 92, 93, 94, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 109, 110, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, ...], 'TV Show': [0, 5, 11, 12, 16, 24, 26, 29, 38, 45, 51, 53, 58, 61, 63, 64, 80, 85, 86, 87, 95, 108, 111, 112, 130, 132, 134, 137, 138, 139, 140, 141, 142, 152, 180, 188, 191, 195, 197, 198, 199, 202, 213, 218, 225, 235, 239, 241, 248, 256, 258, 259, 260, 276, 284, 288, 289, 290, 294, 303, 306, 319, 321, 322, 324, 333, 335, 336, 337, 338, 339, 340, 341, 348, 349, 350, 357, 359, 360, 363, 364, 365, 367, 380, 389, 393, 396, 398, 404, 405, 409, 411, 412, 426, 428, 434, 437, 440, 449, 451, ...]}
